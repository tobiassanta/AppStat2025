# %% [markdown]
# ### Script for reading data for "Blood Pressure" problem in Applied Statistics 2025-26 exam:
#
# The data file contains a header and 2498 entries in two columns:
#  * Patient type (0: Healthy (H0), 1: HyperTension (H1, high blood pressure), and 2: HypoTension (H2, low blood pressure)
#  * Systolic Blood Pressure (in mmHg)
#
# The script was distributed along with the exam and the data file itself on the 15th of January 2026.
#
# ####  Author:
# - Troels Petersen (Niels Bohr Institute, petersen@nbi.dk)
#
# ####  Date:
#  - 10th of January 2026 (latest version)

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('data_BloodPressure.csv', header=0)
ptype, bloodp = dataframe.values.T
dataframe

# %% [markdown]
# Print the first 10 entries to check the content and format of the file:

# %%
for i in range(10):
    print(f"  Patient type: {ptype[i]:7.0f}      Blood Pressure: {bloodp[i]:6.1f} m")
