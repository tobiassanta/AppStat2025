# %% [markdown]
# ### Script for reading data for "Running Times" problem in Applied Statistics 2025-26 exam:
#
# The data file contains a header and 21 entries in three columns:
#  * Distance (in m)
#  * Running time (in seconds)
#  * Running time uncertainty (in seconds)
#
# The script was distributed along with the exam and the data file itself on the 15th of January 2026.
#
# ####  Author:
# - Troels Petersen (Niels Bohr Institute, petersen@nbi.dk)
#
# ####  Date:
#  - 10th of January 2026 (latest version)

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('data_RunningTimes.csv', header=0)
dist, t, sigma_t = dataframe.values.T
dataframe
