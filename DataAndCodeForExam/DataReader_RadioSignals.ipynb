# %% [markdown]
# ### Script for reading data for "Radio Signals" problem in Applied Statistics 2025-26 exam:
#
# The data file contains a header and 99868 entries in two columns:
#  * Frequency (in GHz)
#  * D (Disc temperature index, discriminatory variable against noise)
#  * E (Electronics temperature index, discriminatory variable against noise)
#
# The script was distributed along with the exam and the data file itself on the 15th of January 2026.
#
# ####  Author:
# - Troels Petersen (Niels Bohr Institute, petersen@nbi.dk)
#
# ####  Date:
#  - 10th of January 2026 (latest version)

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('data_RadioSignals.csv', header=0)
freq, a, b = dataframe.values.T
dataframe

# %% [markdown]
# Print the first 10 entries to check the content and format of the file:

# %%
for i in range(10):
    print(f"  Frequency: {freq[i]:7.4f}      D: {a[i]:6.4f}      E: {b[i]:6.4f}")
